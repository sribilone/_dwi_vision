# %%
#import packages

import sys
import numpy as np
import tensorflow as tf
print(tf.__version__)
print(tf.config.list_physical_devices('CPU'))


import os
import cv2
import zipfile
import datetime
import shutil
import itertools
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from enum import Enum
from random import sample
from tensorflow import keras
from patchify import patchify
# from keras_unet_collection import models
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import load_img,img_to_array,ImageDataGenerator
from tensorflow.keras.layers import Dense,Flatten,Dropout,Input, Conv2D, MaxPooling2D, concatenate, Conv2DTranspose

import os
import matplotlib.pyplot as plt
from PIL import Image
# Out:
# 2.7.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# Folder 
original_img_path = 'D:/Sribilone/unburn_2024/All_Dataset/A02-OverlapAMS/OverlapAMS/original/'
label_img_path = 'D:/Sribilone/unburn_2024/All_Dataset/A02-OverlapAMS/OverlapAMS/label/'

# %%
def dullrazor(img):
     # -*- coding: utf-8 -*-
     """
     Following are the DHR tasks followed in this example code:
     
     -- Applying Morphological Black-Hat transformation
     -- Creating the mask for InPainting task
     -- Applying inpainting algorithm on the image
     """

     src = cv2.imread(img)

     # Convert the original image to grayscale
     grayScale = cv2.cvtColor( src, cv2.COLOR_RGB2GRAY )

     # Kernel for the morphological filtering
     kernel = cv2.getStructuringElement(1,(17,17))

     # Perform the blackHat filtering on the grayscale image to find the 
     # hair countours
     blackhat = cv2.morphologyEx(grayScale, cv2.MORPH_BLACKHAT, kernel)

     # intensify the hair countours in preparation for the inpainting 
     # algorithm
     ret,thresh2 = cv2.threshold(blackhat,10,255,cv2.THRESH_BINARY)

     # inpaint the original image depending on the mask
     dst = cv2.inpaint(src,thresh2,1,cv2.INPAINT_TELEA)
    
     return dst

# %%
# get a list of all image filenames in the directory
img_filenames = [f for f in os.listdir(label_img_path) if f.endswith('.tif')]

# define the number of images to display
num_images = 16

# randomly sample num_images images
files_path_ex = np.random.choice(img_filenames, num_images, replace=False)

# %%
# Show the original image

# create a plot to display the images
fig, axs = plt.subplots(4, 4, figsize=(11, 11))
axs = axs.flatten()

# loop through each image filename and plot it
for i, file_path in enumerate(files_path_ex):
    img = Image.open(original_img_path + file_path)
    axs[i].imshow(img)
    axs[i].axis('off')
    axs[i].set_title(file_path)

plt.tight_layout()
plt.show()

# %%
# Show the label image

# create a plot to display the images
fig, axs = plt.subplots(4, 4, figsize=(11, 11))
axs = axs.flatten()

# loop through each image filename and plot it
for i, file_path in enumerate(files_path_ex):
    img = Image.open(label_img_path + file_path)
    axs[i].imshow(img)
    axs[i].axis('off')
    axs[i].set_title(file_path)

plt.tight_layout()
plt.show()

# %%
# Convert image file to .tif format

# loop through each file in the directory
for filename in os.listdir(label_img_path):
    if filename.endswith('.png'):
        # open the image using PIL
        img = Image.open(os.path.join(label_img_path, filename))

        # convert the image to TIFF format
        tif_filename = os.path.splitext(filename)[0] + '.tif'
        img.save(os.path.join(label_img_path, tif_filename))

        # delete the original JPEG file
        os.remove(os.path.join(label_img_path, filename))

# %%
# Get a list of all the image filenames in the directory
images_path_label = [f for f in os.listdir(label_img_path) if f.endswith('.tif')]

# Loop through each image and read it using PIL
for image_filename in images_path_label:
    image_path = os.path.join(label_img_path, image_filename)
#     with Image.open(image_path) as im:
#         # Do something with the image, for example:
#         im.show()

# %%
# Get a list of all the image filenames in the directory
images_path_original = [f for f in os.listdir(original_img_path) if f.endswith('.tif')]

# Loop through each image and read it using PIL
for image_filename in images_path_original:
    image_path = os.path.join(original_img_path, image_filename)

# %%
path_original = original_img_path # 'C:/Users/korawitkj/Documents/Conda_env/unburn_dataset_ajkwan/Original/'
path_label = label_img_path #'C:/Users/korawitkj/Documents/Conda_env/unburn_dataset_ajkwan/Labelled/'

# %%
for root, dirs, files in os.walk(original_img_path):
    for file in files:
        if '-' in file:
            new_file_name = file.replace('-', '') # remove hyphens from the file name
            counter = 1
            while os.path.exists(os.path.join(root, new_file_name)):
                new_file_name = f"{os.path.splitext(file)[0]}_{counter}{os.path.splitext(file)[1]}"
                counter += 1
            os.rename(os.path.join(root, file), os.path.join(root, new_file_name))

# %%
path_label
# Out:
# 'D:/Sribilone/unburn_2024/All_Dataset/A02-OverlapAMS/OverlapAMS/label/'

# %%
path_original
# Out:
# 'D:/Sribilone/unburn_2024/All_Dataset/A02-OverlapAMS/OverlapAMS/original/'

# %%
images_path_original
# Out:
# ['01.tif',
#  '02.tif',
#  '03.tif',
#  '04.tif',
#  '05.tif',
#  '06.tif',
#  '07.tif',
#  '08.tif',
#  '09.tif',
#  '10.tif',
#  '100.tif',
#  '1000.tif',
#  '101.tif',
#  '102.tif',
#  '103.tif',
#  '104.tif',
#  '105.tif',
#  '106.tif',
#  '107.tif',
#  '108.tif',
#  '109.tif',
#  '11.tif',
#  '110.tif',
#  '111.tif',
#  '112.tif',
#  '113.tif',
#  '114.tif',
#  '115.tif',
#  '116.tif',
#  '117.tif',
#  '118.tif',
#  '119.tif',
#  '12.tif',
#  '120.tif',
#  '121.tif',
#  '122.tif',
#  '123.tif',
#  '124.tif',
#  '125.tif',
#  '126.tif',
#  '127.tif',
#  '128.tif',
#  '129.tif',
#  '13.tif',
#  '130.tif',
#  '131.tif',
#  '132.tif',
#  '133.tif',
#  '134.tif',
#  '135.tif',
#  '136.tif',
#  '137.tif',
#  '138.tif',
#  '139.tif',
#  '14.tif',
#  '140.tif',
#  '141.tif',
#  '142.tif',
#  '143.tif',
#  '144.tif',
#  '145.tif',
#  '146.tif',
#  '147.tif',
#  '148.tif',
#  '149.tif',
#  '15.tif',
#  '150.tif',
#  '151.tif',
#  '152.tif',
#  '153.tif',
#  '154.tif',
#  '155.tif',
#  '156.tif',
#  '157.tif',
#  '158.tif',
#  '159.tif',
#  '16.tif',
#  '160.tif',
#  '161.tif',
#  '162.tif',
#  '163.tif',
#  '164.tif',
#  '165.tif',
#  '166.tif',
#  '167.tif',
#  '168.tif',
#  '169.tif',
#  '17.tif',
#  '170.tif',
#  '171.tif',
#  '172.tif',
#  '173.tif',
#  '174.tif',
#  '175.tif',
#  '176.tif',
#  '177.tif',
#  '178.tif',
#  '179.tif',
#  '18.tif',
#  '180.tif',
#  '181.tif',
#  '182.tif',
#  '183.tif',
#  '184.tif',
#  '185.tif',
#  '186.tif',
#  '187.tif',
#  '188.tif',
#  '189.tif',
#  '19.tif',
#  '190.tif',
#  '191.tif',
#  '192.tif',
#  '193.tif',
#  '194.tif',
#  '195.tif',
#  '196.tif',
#  '197.tif',
#  '198.tif',
#  '199.tif',
#  '20.tif',
#  '200.tif',
#  '201.tif',
#  '202.tif',
#  '203.tif',
#  '204.tif',
#  '205.tif',
#  '206.tif',
#  '207.tif',
#  '208.tif',
#  '209.tif',
#  '21.tif',
#  '210.tif',
#  '211.tif',
#  '212.tif',
#  '213.tif',
#  '214.tif',
#  '215.tif',
#  '216.tif',
#  '217.tif',
#  '218.tif',
#  '219.tif',
#  '22.tif',
#  '220.tif',
#  '221.tif',
#  '222.tif',
#  '223.tif',
#  '224.tif',
#  '225.tif',
#  '226.tif',
#  '227.tif',
#  '228.tif',
#  '229.tif',
#  '23.tif',
#  '230.tif',
#  '231.tif',
#  '232.tif',
#  '233.tif',
#  '234.tif',
#  '235.tif',
#  '236.tif',
#  '237.tif',
#  '238.tif',
#  '239.tif',
#  '24.tif',
#  '240.tif',
#  '241.tif',
#  '242.tif',
#  '243.tif',
#  '244.tif',
#  '245.tif',
#  '246.tif',
#  '247.tif',
#  '248.tif',
#  '249.tif',
#  '25.tif',
#  '250.tif',
#  '251.tif',
#  '252.tif',
#  '253.tif',
#  '254.tif',
#  '255.tif',
#  '256.tif',
#  '257.tif',
#  '258.tif',
#  '259.tif',
#  '26.tif',
#  '260.tif',
#  '261.tif',
#  '262.tif',
#  '263.tif',
#  '264.tif',
#  '265.tif',
#  '266.tif',
#  '267.tif',
#  '268.tif',
#  '269.tif',
#  '27.tif',
#  '270.tif',
#  '271.tif',
#  '272.tif',
#  '273.tif',
#  '274.tif',
#  '275.tif',
#  '276.tif',
#  '277.tif',
#  '278.tif',
#  '279.tif',
#  '28.tif',
#  '280.tif',
#  '281.tif',
#  '282.tif',
#  '283.tif',
#  '284.tif',
#  '285.tif',
#  '286.tif',
#  '287.tif',
#  '288.tif',
#  '289.tif',
#  '29.tif',
#  '290.tif',
#  '291.tif',
#  '292.tif',
#  '293.tif',
#  '294.tif',
#  '295.tif',
#  '296.tif',
#  '297.tif',
#  '298.tif',
#  '299.tif',
#  '30.tif',
#  '300.tif',
#  '301.tif',
#  '302.tif',
#  '303.tif',
#  '304.tif',
#  '305.tif',
#  '306.tif',
#  '307.tif',
#  '308.tif',
#  '309.tif',
#  '31.tif',
#  '310.tif',
#  '311.tif',
#  '312.tif',
#  '313.tif',
#  '314.tif',
#  '315.tif',
#  '316.tif',
#  '317.tif',
#  '318.tif',
#  '319.tif',
#  '32.tif',
#  '320.tif',
#  '321.tif',
#  '322.tif',
#  '323.tif',
#  '324.tif',
#  '325.tif',
#  '326.tif',
#  '327.tif',
#  '328.tif',
#  '329.tif',
#  '33.tif',
#  '330.tif',
#  '331.tif',
#  '332.tif',
#  '333.tif',
#  '334.tif',
#  '335.tif',
#  '336.tif',
#  '337.tif',
#  '338.tif',
#  '339.tif',
#  '34.tif',
#  '340.tif',
#  '341.tif',
#  '342.tif',
#  '343.tif',
#  '344.tif',
#  '345.tif',
#  '346.tif',
#  '347.tif',
#  '348.tif',
#  '349.tif',
#  '35.tif',
#  '350.tif',
#  '351.tif',
#  '352.tif',
#  '353.tif',
#  '354.tif',
#  '355.tif',
#  '356.tif',
#  '357.tif',
#  '358.tif',
#  '359.tif',
#  '36.tif',
#  '360.tif',
#  '361.tif',
#  '362.tif',
#  '363.tif',
#  '364.tif',
#  '365.tif',
#  '366.tif',
#  '367.tif',
#  '368.tif',
#  '369.tif',
#  '37.tif',
#  '370.tif',
#  '371.tif',
#  '372.tif',
#  '373.tif',
#  '374.tif',
#  '375.tif',
#  '376.tif',
#  '377.tif',
#  '378.tif',
#  '379.tif',
#  '38.tif',
#  '380.tif',
#  '381.tif',
#  '382.tif',
#  '383.tif',
#  '384.tif',
#  '385.tif',
#  '386.tif',
#  '387.tif',
#  '388.tif',
#  '389.tif',
#  '39.tif',
#  '390.tif',
#  '391.tif',
#  '392.tif',
#  '393.tif',
#  '394.tif',
#  '395.tif',
#  '396.tif',
#  '397.tif',
#  '398.tif',
#  '399.tif',
#  '40.tif',
#  '400.tif',
#  '401.tif',
#  '402.tif',
#  '403.tif',
#  '404.tif',
#  '405.tif',
#  '406.tif',
#  '407.tif',
#  '408.tif',
#  '409.tif',
#  '41.tif',
#  '410.tif',
#  '411.tif',
#  '412.tif',
#  '413.tif',
#  '414.tif',
#  '415.tif',
#  '416.tif',
#  '417.tif',
#  '418.tif',
#  '419.tif',
#  '42.tif',
#  '420.tif',
#  '421.tif',
#  '422.tif',
#  '423.tif',
#  '424.tif',
#  '425.tif',
#  '426.tif',
#  '427.tif',
#  '428.tif',
#  '429.tif',
#  '43.tif',
#  '430.tif',
#  '431.tif',
#  '432.tif',
#  '433.tif',
#  '434.tif',
#  '435.tif',
#  '436.tif',
#  '437.tif',
#  '438.tif',
#  '439.tif',
#  '44.tif',
#  '440.tif',
#  '441.tif',
#  '442.tif',
#  '443.tif',
#  '444.tif',
#  '445.tif',
#  '446.tif',
#  '447.tif',
#  '448.tif',
#  '449.tif',
#  '45.tif',
#  '450.tif',
#  '451.tif',
#  '452.tif',
#  '453.tif',
#  '454.tif',
#  '455.tif',
#  '456.tif',
#  '457.tif',
#  '458.tif',
#  '459.tif',
#  '46.tif',
#  '460.tif',
#  '461.tif',
#  '462.tif',
#  '463.tif',
#  '464.tif',
#  '465.tif',
#  '466.tif',
#  '467.tif',
#  '468.tif',
#  '469.tif',
#  '47.tif',
#  '470.tif',
#  '471.tif',
#  '472.tif',
#  '473.tif',
#  '474.tif',
#  '475.tif',
#  '476.tif',
#  '477.tif',
#  '478.tif',
#  '479.tif',
#  '48.tif',
#  '480.tif',
#  '481.tif',
#  '482.tif',
#  '483.tif',
#  '484.tif',
#  '485.tif',
#  '486.tif',
#  '487.tif',
#  '488.tif',
#  '489.tif',
#  '49.tif',
#  '490.tif',
#  '491.tif',
#  '492.tif',
#  '493.tif',
#  '494.tif',
#  '495.tif',
#  '496.tif',
#  '497.tif',
#  '498.tif',
#  '499.tif',
#  '50.tif',
#  '500.tif',
#  '501.tif',
#  '502.tif',
#  '503.tif',
#  '504.tif',
#  '505.tif',
#  '506.tif',
#  '507.tif',
#  '508.tif',
#  '509.tif',
#  '51.tif',
#  '510.tif',
#  '511.tif',
#  '512.tif',
#  '513.tif',
#  '514.tif',
#  '515.tif',
#  '516.tif',
#  '517.tif',
#  '518.tif',
#  '519.tif',
#  '52.tif',
#  '520.tif',
#  '521.tif',
#  '522.tif',
#  '523.tif',
#  '524.tif',
#  '525.tif',
#  '526.tif',
#  '527.tif',
#  '528.tif',
#  '529.tif',
#  '53.tif',
#  '530.tif',
#  '531.tif',
#  '532.tif',
#  '533.tif',
#  '534.tif',
#  '535.tif',
#  '536.tif',
#  '537.tif',
#  '538.tif',
#  '539.tif',
#  '54.tif',
#  '540.tif',
#  '541.tif',
#  '542.tif',
#  '543.tif',
#  '544.tif',
#  '545.tif',
#  '546.tif',
#  '547.tif',
#  '548.tif',
#  '549.tif',
#  '55.tif',
#  '550.tif',
#  '551.tif',
#  '552.tif',
#  '553.tif',
#  '554.tif',
#  '555.tif',
#  '556.tif',
#  '557.tif',
#  '558.tif',
#  '559.tif',
#  '56.tif',
#  '560.tif',
#  '561.tif',
#  '562.tif',
#  '563.tif',
#  '564.tif',
#  '565.tif',
#  '566.tif',
#  '567.tif',
#  '568.tif',
#  '569.tif',
#  '57.tif',
#  '570.tif',
#  '571.tif',
#  '572.tif',
#  '573.tif',
#  '574.tif',
#  '575.tif',
#  '576.tif',
#  '577.tif',
#  '578.tif',
#  '579.tif',
#  '58.tif',
#  '580.tif',
#  '581.tif',
#  '582.tif',
#  '583.tif',
#  '584.tif',
#  '585.tif',
#  '586.tif',
#  '587.tif',
#  '588.tif',
#  '589.tif',
#  '59.tif',
#  '590.tif',
#  '591.tif',
#  '592.tif',
#  '593.tif',
#  '594.tif',
#  '595.tif',
#  '596.tif',
#  '597.tif',
#  '598.tif',
#  '599.tif',
#  '60.tif',
#  '600.tif',
#  '601.tif',
#  '602.tif',
#  '603.tif',
#  '604.tif',
#  '605.tif',
#  '606.tif',
#  '607.tif',
#  '608.tif',
#  '609.tif',
#  '61.tif',
#  '610.tif',
#  '611.tif',
#  '612.tif',
#  '613.tif',
#  '614.tif',
#  '615.tif',
#  '616.tif',
#  '617.tif',
#  '618.tif',
#  '619.tif',
#  '62.tif',
#  '620.tif',
#  '621.tif',
#  '622.tif',
#  '623.tif',
#  '624.tif',
#  '625.tif',
#  '626.tif',
#  '627.tif',
#  '628.tif',
#  '629.tif',
#  '63.tif',
#  '630.tif',
#  '631.tif',
#  '632.tif',
#  '633.tif',
#  '634.tif',
#  '635.tif',
#  '636.tif',
#  '637.tif',
#  '638.tif',
#  '639.tif',
#  '64.tif',
#  '640.tif',
#  '641.tif',
#  '642.tif',
#  '643.tif',
#  '644.tif',
#  '645.tif',
#  '646.tif',
#  '647.tif',
#  '648.tif',
#  '649.tif',
#  '65.tif',
#  '650.tif',
#  '651.tif',
#  '652.tif',
#  '653.tif',
#  '654.tif',
#  '655.tif',
#  '656.tif',
#  '657.tif',
#  '658.tif',
#  '659.tif',
#  '66.tif',
#  '660.tif',
#  '661.tif',
#  '662.tif',
#  '663.tif',
#  '664.tif',
#  '665.tif',
#  '666.tif',
#  '667.tif',
#  '668.tif',
#  '669.tif',
#  '67.tif',
#  '670.tif',
#  '671.tif',
#  '672.tif',
#  '673.tif',
#  '674.tif',
#  '675.tif',
#  '676.tif',
#  '677.tif',
#  '678.tif',
#  '679.tif',
#  '68.tif',
#  '680.tif',
#  '681.tif',
#  '682.tif',
#  '683.tif',
#  '684.tif',
#  '685.tif',
#  '686.tif',
#  '687.tif',
#  '688.tif',
#  '689.tif',
#  '69.tif',
#  '690.tif',
#  '691.tif',
#  '692.tif',
#  '693.tif',
#  '694.tif',
#  '695.tif',
#  '696.tif',
#  '697.tif',
#  '698.tif',
#  '699.tif',
#  '70.tif',
#  '700.tif',
#  '701.tif',
#  '702.tif',
#  '703.tif',
#  '704.tif',
#  '705.tif',
#  '706.tif',
#  '707.tif',
#  '708.tif',
#  '709.tif',
#  '71.tif',
#  '710.tif',
#  '711.tif',
#  '712.tif',
#  '713.tif',
#  '714.tif',
#  '715.tif',
#  '716.tif',
#  '717.tif',
#  '718.tif',
#  '719.tif',
#  '72.tif',
#  '720.tif',
#  '721.tif',
#  '722.tif',
#  '723.tif',
#  '724.tif',
#  '725.tif',
#  '726.tif',
#  '727.tif',
#  '728.tif',
#  '729.tif',
#  '73.tif',
#  '730.tif',
#  '731.tif',
#  '732.tif',
#  '733.tif',
#  '734.tif',
#  '735.tif',
#  '736.tif',
#  '737.tif',
#  '738.tif',
#  '739.tif',
#  '74.tif',
#  '740.tif',
#  '741.tif',
#  '742.tif',
#  '743.tif',
#  '744.tif',
#  '745.tif',
#  '746.tif',
#  '747.tif',
#  '748.tif',
#  '749.tif',
#  '75.tif',
#  '750.tif',
#  '751.tif',
#  '752.tif',
#  '753.tif',
#  '754.tif',
#  '755.tif',
#  '756.tif',
#  '757.tif',
#  '758.tif',
#  '759.tif',
#  '76.tif',
#  '760.tif',
#  '761.tif',
#  '762.tif',
#  '763.tif',
#  '764.tif',
#  '765.tif',
#  '766.tif',
#  '767.tif',
#  '768.tif',
#  '769.tif',
#  '77.tif',
#  '770.tif',
#  '771.tif',
#  '772.tif',
#  '773.tif',
#  '774.tif',
#  '775.tif',
#  '776.tif',
#  '777.tif',
#  '778.tif',
#  '779.tif',
#  '78.tif',
#  '780.tif',
#  '781.tif',
#  '782.tif',
#  '783.tif',
#  '784.tif',
#  '785.tif',
#  '786.tif',
#  '787.tif',
#  '788.tif',
#  '789.tif',
#  '79.tif',
#  '790.tif',
#  '791.tif',
#  '792.tif',
#  '793.tif',
#  '794.tif',
#  '795.tif',
#  '796.tif',
#  '797.tif',
#  '798.tif',
#  '799.tif',
#  '80.tif',
#  '800.tif',
#  '801.tif',
#  '802.tif',
#  '803.tif',
#  '804.tif',
#  '805.tif',
#  '806.tif',
#  '807.tif',
#  '808.tif',
#  '809.tif',
#  '81.tif',
#  '810.tif',
#  '811.tif',
#  '812.tif',
#  '813.tif',
#  '814.tif',
#  '815.tif',
#  '816.tif',
#  '817.tif',
#  '818.tif',
#  '819.tif',
#  '82.tif',
#  '820.tif',
#  '821.tif',
#  '822.tif',
#  '823.tif',
#  '824.tif',
#  '825.tif',
#  '826.tif',
#  '827.tif',
#  '828.tif',
#  '829.tif',
#  '83.tif',
#  '830.tif',
#  '831.tif',
#  '832.tif',
#  '833.tif',
#  '834.tif',
#  '835.tif',
#  '836.tif',
#  '837.tif',
#  '838.tif',
#  '839.tif',
#  '84.tif',
#  '840.tif',
#  '841.tif',
#  '842.tif',
#  '843.tif',
#  '844.tif',
#  '845.tif',
#  '846.tif',
#  '847.tif',
#  '848.tif',
#  '849.tif',
#  '85.tif',
#  '850.tif',
#  '851.tif',
#  '852.tif',
#  '853.tif',
#  '854.tif',
#  '855.tif',
#  '856.tif',
#  '857.tif',
#  '858.tif',
#  '859.tif',
#  '86.tif',
#  '860.tif',
#  '861.tif',
#  '862.tif',
#  '863.tif',
#  '864.tif',
#  '865.tif',
#  '866.tif',
#  '867.tif',
#  '868.tif',
#  '869.tif',
#  '87.tif',
#  '870.tif',
#  '871.tif',
#  '872.tif',
#  '873.tif',
#  '874.tif',
#  '875.tif',
#  '876.tif',
#  '877.tif',
#  '878.tif',
#  '879.tif',
#  '88.tif',
#  '880.tif',
#  '881.tif',
#  '882.tif',
#  '883.tif',
#  '884.tif',
#  '885.tif',
#  '886.tif',
#  '887.tif',
#  '888.tif',
#  '889.tif',
#  '89.tif',
#  '890.tif',
#  '891.tif',
#  '892.tif',
#  '893.tif',
#  '894.tif',
#  '895.tif',
#  '896.tif',
#  '897.tif',
#  '898.tif',
#  '899.tif',
#  '90.tif',
#  '900.tif',
#  '901.tif',
#  '902.tif',
#  '903.tif',
#  '904.tif',
#  '905.tif',
#  '906.tif',
#  '907.tif',
#  '908.tif',
#  '909.tif',
#  '91.tif',
#  '910.tif',
#  '911.tif',
#  '912.tif',
#  '913.tif',
#  '914.tif',
#  '915.tif',
#  '916.tif',
#  '917.tif',
#  '918.tif',
#  '919.tif',
#  '92.tif',
#  '920.tif',
#  '921.tif',
#  '922.tif',
#  '923.tif',
#  '924.tif',
#  '925.tif',
#  '926.tif',
#  '927.tif',
#  '928.tif',
#  '929.tif',
#  '93.tif',
#  '930.tif',
#  '931.tif',
#  '932.tif',
#  '933.tif',
#  '934.tif',
#  '935.tif',
#  '936.tif',
#  '937.tif',
#  '938.tif',
#  '939.tif',
#  '94.tif',
#  '940.tif',
#  '941.tif',
#  '942.tif',
#  '943.tif',
#  '944.tif',
#  '945.tif',
#  '946.tif',
#  '947.tif',
#  '948.tif',
#  '949.tif',
#  '95.tif',
#  '950.tif',
#  '951.tif',
#  '952.tif',
#  '953.tif',
#  '954.tif',
#  '955.tif',
#  '956.tif',
#  '957.tif',
#  '958.tif',
#  '959.tif',
#  '96.tif',
#  '960.tif',
#  '961.tif',
#  '962.tif',
#  '963.tif',
#  '964.tif',
#  '965.tif',
#  '966.tif',
#  '967.tif',
#  '968.tif',
#  '969.tif',
#  '97.tif',
#  '970.tif',
#  '971.tif',
#  '972.tif',
#  '973.tif',
#  '974.tif',
#  '975.tif',
#  '976.tif',
#  '977.tif',
#  '978.tif',
#  '979.tif',
#  '98.tif',
#  '980.tif',
#  '981.tif',
#  '982.tif',
#  '983.tif',
#  '984.tif',
#  '985.tif',
#  '986.tif',
#  '987.tif',
#  '988.tif',
#  '989.tif',
#  '99.tif',
#  '990.tif',
#  '991.tif',
#  '992.tif',
#  '993.tif',
#  '994.tif',
#  '995.tif',
#  '996.tif',
#  '997.tif',
#  '998.tif',
#  '999.tif']

# %%
pd.DataFrame(images_path_label)
# Out:
#            0
# 0     01.tif
# 1     02.tif
# 2     03.tif
# 3     04.tif
# 4     05.tif
# ..       ...
# 995  995.tif
# 996  996.tif
# 997  997.tif
# 998  998.tif
# 999  999.tif
#
# [1000 rows x 1 columns]

# %%
from enum import Enum
class MaskColorMap(Enum):
    class_blue = (0, 0 ,254)
    class_green = (0, 255, 0)
    clas_whtie = (255, 255, 255)

n_classes = 3
U_net_class = ['class_blue', 'class_green', 'clas_whtie']

# %%
def load_images_and_patchify(img_path, patch_size):
    """
    :param patch_size: image patchify square size
    :param directory_path: path to root directory containing training and test images
    :return: list of images from directory
    """
    # initialize empty list for images
    instances = []
    # Reads image 
    image = img_to_array(load_img(img_path,target_size=(patch_size,patch_size)),dtype=np.uint8)

    # Extract patches from each image, step=patch_size means no overlap
    patch_img = patchify(image, (patch_size, patch_size, 3), step=patch_size)
    
    # iterate over vertical patch axis
    for j in range(patch_img.shape[0]):
        # iterate over horizontal patch axis
        for k in range(patch_img.shape[1]):
            # patches are located like a grid. use (j, k) indices to extract single patched image
            single_patch_img = patch_img[j, k]
            # Drop extra extra dimension from patchify
            instances.append(np.squeeze(single_patch_img))

    return instances

# %%
# !conda install pillow

# %%
def get_training_data(list_image, images_original,images_label, patch_size):
    # initialise lists
    image_dataset, mask_dataset = [], []

    # walk through root directory
    for i in tqdm(list_image):
        image_dataset.extend(load_images_and_patchify(images_original+i, patch_size=patch_size))
        mask_dataset.extend(load_images_and_patchify(images_label+i, patch_size=patch_size))

    # return input images and masks
    return np.array(image_dataset), np.array(mask_dataset)

# %%
X,Y = get_training_data(list_image = images_path_label, images_original = path_original, images_label= path_label, patch_size=224 )
# Out:
# 100%|██████████| 1000/1000 [00:14<00:00, 68.71it/s]

# %%
# Test
# D:/Sribilone/unburn_2024/All_Dataset/A02-OverlapAMS/OverlapAMS/test/label
# D:/Sribilone/unburn_2024/All_Dataset/A02-OverlapAMS/OverlapAMS/test/original

# %%
ori_test = 'D:/Sribilone/unburn_2024/All_Dataset/A02-OverlapAMS/OverlapAMS/test/label/'
label_test = ' D:/Sribilone/unburn_2024/All_Dataset/A02-OverlapAMS/OverlapAMS/test/original/'

# %%
# Get a list of all the image filenames in the directory
images_path_label_test = [f for f in os.listdir(ori_test) if f.endswith('.tif')]

# Loop through each image and read it using PIL
for image_filename in images_path_label_test:
    image_path = os.path.join(ori_test, image_filename)
#     with Image.open(image_path) as im:
#         # Do something with the image, for example:
#         im.show()

# %%
images_path_label_test
# Out:
# ['01.tif',
#  '02.tif',
#  '03.tif',
#  '04.tif',
#  '05.tif',
#  '06.tif',
#  '07.tif',
#  '08.tif',
#  '09.tif',
#  '10.tif']

# %%
ori_test
# Out:
# 'D:/Sribilone/unburn_2024/All_Dataset/A02-OverlapAMS/OverlapAMS/test/label/'

# %%
X_testimg,Y_testimg  = get_training_data(list_image = images_path_label_test, images_original = path_original, images_label= path_label, patch_size=224 )
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 66.23it/s]

# %%
m, img_height, img_width, img_channels = X.shape

# %%
def display_images(instances, rows=2, titles=None):
    """
    :param instances:  list of images
    :param rows: number of rows in subplot
    :param titles: subplot titles
    :return:
    """
    n = len(instances)
    cols = n // rows if (n / rows) % rows == 0 else (n // rows) + 1
    # Display Input Images and Target Labels
    plt.figure(figsize = (10,10),constrained_layout=True)
    for j, image in enumerate(instances):
        plt.subplot(4, 4, j + 1)
        plt.title('') if titles is None else plt.title(titles[j])
        plt.imshow(image)

# %%
display_count = 6
random_index = [np.random.randint(0, m) for _ in range(display_count)]
sample_images = [x for z in zip(list(X[random_index]), list(Y[random_index])) for x in z]
display_images(sample_images, rows=3)

# %%
def one_hot_encode_masks(masks, num_classes):
    """
    :param masks: Y_train patched mask dataset
    :param num_classes: number of classes
    :return:
    """
    # initialise list for integer encoded masks
    integer_encoded_labels = []

    # iterate over each mask
    for mask in tqdm(masks):

        # get image shape
        _img_height, _img_width, _img_channels = mask.shape

        # create new mask of zeros
        encoded_image = np.zeros((_img_height, _img_width, 1)).astype(int)

        for j, cls in enumerate(MaskColorMap):
            encoded_image[np.all(mask == cls.value, axis=-1)] = j

        # append encoded image
        integer_encoded_labels.append(encoded_image)

    # return one-hot encoded labels
    return to_categorical(y=integer_encoded_labels, num_classes=num_classes)

# %%
# jaccard similarity: the size of the intersection divided by the size of the union of two sets
from keras import backend as K
def jaccard_index(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

# %%
# convert RGB values to ineger encoded labels for categorial_crossentropy
Y_unet = one_hot_encode_masks(Y, num_classes=3)
# Out:
# 100%|██████████| 1000/1000 [00:03<00:00, 319.55it/s]

# %%
Y_unet_test = one_hot_encode_masks(Y_testimg, num_classes=3)
# X_testimg,Y_testimg
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 270.29it/s]

# %%
print('Amount of X_testimg data:', X_testimg.shape[0])
# print('Amount of test data:', X_test.shape[0])
# Out:
# Amount of X_testimg data: 10

# %%
# split dataset into training and test groups
X_train, X_test, Y_train, Y_test = train_test_split(X, Y_unet, test_size=0.2, random_state=42)

# %%
print('Amount of X_train data:', X_train.shape[0])
print('Amount of test data:', X_test.shape[0])
# Out:
# Amount of X_train data: 800
# Amount of test data: 200

# %%
# define U-Net model architecture
def build_unet(img_shape):
    # input layer shape is equal to patch image size
    inputs = Input(shape=img_shape)

    # rescale images from (0, 255) to (0, 1)
    rescale = Rescaling(scale=1. / 255, input_shape=(img_height, img_width, img_channels))(inputs)
    previous_block_activation = rescale  # Set aside residual

    contraction = {}
    # # Contraction path: Blocks 1 through 5 are identical apart from the feature depth
    for f in [16, 32, 64, 128]:
        x = Conv2D(f, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(previous_block_activation)
        x = Dropout(0.1)(x)
        x = Conv2D(f, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(x)
        contraction[f'conv{f}'] = x
        x = MaxPooling2D((2, 2))(x)
        previous_block_activation = x

    c5 = Conv2D(160, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(previous_block_activation)
    c5 = Dropout(0.2)(c5)
    c5 = Conv2D(160, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
    previous_block_activation = c5

    # Expansive path: Second half of the network: upsampling inputs
    for f in reversed([16, 32, 64, 128]):
        x = Conv2DTranspose(f, (2, 2), strides=(2, 2), padding='same')(previous_block_activation)
        x = concatenate([x, contraction[f'conv{f}']])
        x = Conv2D(f, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(x)
        x = Dropout(0.2)(x)
        x = Conv2D(f, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(x)
        previous_block_activation = x

    outputs = Conv2D(filters=n_classes, kernel_size=(1, 1), activation="softmax")(previous_block_activation)

    return Model(inputs=inputs, outputs=outputs)

# %%
# build model
model_U = build_unet(img_shape=(img_height, img_width, img_channels))
model_U.summary()
model_U.compile(optimizer="adam", loss="categorical_crossentropy",
              metrics=["accuracy",jaccard_index])
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling_7 (Rescaling)        (None, 224, 224, 3)  0           ['input_8[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 224, 224, 16  448         ['rescaling_7[0][0]']
#                                 )
#
#  dropout_63 (Dropout)           (None, 224, 224, 16  0           ['conv2d_133[0][0]']
#                                 )
#
#  conv2d_134 (Conv2D)            (None, 224, 224, 16  2320        ['dropout_63[0][0]']
#                                 )
#
#  max_pooling2d_28 (MaxPooling2D  (None, 112, 112, 16  0          ['conv2d_134[0][0]']
#  )                              )
#
#  conv2d_135 (Conv2D)            (None, 112, 112, 32  4640        ['max_pooling2d_28[0][0]']
#                                 )
#
#  dropout_64 (Dropout)           (None, 112, 112, 32  0           ['conv2d_135[0][0]']
#                                 )
#
#  conv2d_136 (Conv2D)            (None, 112, 112, 32  9248        ['dropout_64[0][0]']
#                                 )
#
#  max_pooling2d_29 (MaxPooling2D  (None, 56, 56, 32)  0           ['conv2d_136[0][0]']
#  )
#
#  conv2d_137 (Conv2D)            (None, 56, 56, 64)   18496       ['max_pooling2d_29[0][0]']
#
#  dropout_65 (Dropout)           (None, 56, 56, 64)   0           ['conv2d_137[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 56, 56, 64)   36928       ['dropout_65[0][0]']
#
#  max_pooling2d_30 (MaxPooling2D  (None, 28, 28, 64)  0           ['conv2d_138[0][0]']
#  )
#
#  conv2d_139 (Conv2D)            (None, 28, 28, 128)  73856       ['max_pooling2d_30[0][0]']
#
#  dropout_66 (Dropout)           (None, 28, 28, 128)  0           ['conv2d_139[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 28, 28, 128)  147584      ['dropout_66[0][0]']
#
#  max_pooling2d_31 (MaxPooling2D  (None, 14, 14, 128)  0          ['conv2d_140[0][0]']
#  )
#
#  conv2d_141 (Conv2D)            (None, 14, 14, 160)  184480      ['max_pooling2d_31[0][0]']
#
#  dropout_67 (Dropout)           (None, 14, 14, 160)  0           ['conv2d_141[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 14, 14, 160)  230560      ['dropout_67[0][0]']
#
#  conv2d_transpose_28 (Conv2DTra  (None, 28, 28, 128)  82048      ['conv2d_142[0][0]']
#  nspose)
#
#  concatenate_28 (Concatenate)   (None, 28, 28, 256)  0           ['conv2d_transpose_28[0][0]',
#                                                                   'conv2d_140[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 28, 28, 128)  295040      ['concatenate_28[0][0]']
#
#  dropout_68 (Dropout)           (None, 28, 28, 128)  0           ['conv2d_143[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 28, 28, 128)  147584      ['dropout_68[0][0]']
#
#  conv2d_transpose_29 (Conv2DTra  (None, 56, 56, 64)  32832       ['conv2d_144[0][0]']
#  nspose)
#
#  concatenate_29 (Concatenate)   (None, 56, 56, 128)  0           ['conv2d_transpose_29[0][0]',
#                                                                   'conv2d_138[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 56, 56, 64)   73792       ['concatenate_29[0][0]']
#
#  dropout_69 (Dropout)           (None, 56, 56, 64)   0           ['conv2d_145[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 56, 56, 64)   36928       ['dropout_69[0][0]']
#
#  conv2d_transpose_30 (Conv2DTra  (None, 112, 112, 32  8224       ['conv2d_146[0][0]']
#  nspose)                        )
#
#  concatenate_30 (Concatenate)   (None, 112, 112, 64  0           ['conv2d_transpose_30[0][0]',
#                                 )                                 'conv2d_136[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 112, 112, 32  18464       ['concatenate_30[0][0]']
#                                 )
#
#  dropout_70 (Dropout)           (None, 112, 112, 32  0           ['conv2d_147[0][0]']
#                                 )
#
#  conv2d_148 (Conv2D)            (None, 112, 112, 32  9248        ['dropout_70[0][0]']
#                                 )
#
#  conv2d_transpose_31 (Conv2DTra  (None, 224, 224, 16  2064       ['conv2d_148[0][0]']
#  nspose)                        )
#
#  concatenate_31 (Concatenate)   (None, 224, 224, 32  0           ['conv2d_transpose_31[0][0]',
#                                 )                                 'conv2d_134[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 224, 224, 16  4624        ['concatenate_31[0][0]']
#                                 )
#
#  dropout_71 (Dropout)           (None, 224, 224, 16  0           ['conv2d_149[0][0]']
#                                 )
#
#  conv2d_150 (Conv2D)            (None, 224, 224, 16  2320        ['dropout_71[0][0]']
#                                 )
#
#  conv2d_151 (Conv2D)            (None, 224, 224, 3)  51          ['conv2d_150[0][0]']
#
# ==================================================================================================
# Total params: 1,421,779
# Trainable params: 1,421,779
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
print(X_train.shape)
print(X_train.dtype)
# Out:
# (800, 224, 224, 3)
# uint8

# %%
# train and save model
# with tf.device('/gpu:0'):
history = model_U.fit(X_train, Y_train, epochs=200, batch_size=16, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/200
# 50/50 [==============================] - 5s 48ms/step - loss: 0.9146 - accuracy: 0.6343 - jaccard_index: 0.3049 - val_loss: 0.8475 - val_accuracy: 0.6905 - val_jaccard_index: 0.2921
# Epoch 2/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.7580 - accuracy: 0.6917 - jaccard_index: 0.3811 - val_loss: 0.6652 - val_accuracy: 0.7149 - val_jaccard_index: 0.3925
# Epoch 3/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.6513 - accuracy: 0.7179 - jaccard_index: 0.4360 - val_loss: 0.6614 - val_accuracy: 0.7116 - val_jaccard_index: 0.4419
# Epoch 4/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.6164 - accuracy: 0.7246 - jaccard_index: 0.4483 - val_loss: 0.5853 - val_accuracy: 0.7306 - val_jaccard_index: 0.4377
# Epoch 5/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.5720 - accuracy: 0.7365 - jaccard_index: 0.4740 - val_loss: 0.5917 - val_accuracy: 0.7307 - val_jaccard_index: 0.4615
# Epoch 6/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.5511 - accuracy: 0.7460 - jaccard_index: 0.4920 - val_loss: 0.5770 - val_accuracy: 0.7404 - val_jaccard_index: 0.4685
# Epoch 7/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.5258 - accuracy: 0.7598 - jaccard_index: 0.5087 - val_loss: 0.6153 - val_accuracy: 0.7345 - val_jaccard_index: 0.4612
# Epoch 8/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.5101 - accuracy: 0.7670 - jaccard_index: 0.5199 - val_loss: 0.5757 - val_accuracy: 0.7513 - val_jaccard_index: 0.4604
# Epoch 9/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.4996 - accuracy: 0.7741 - jaccard_index: 0.5299 - val_loss: 0.5498 - val_accuracy: 0.7458 - val_jaccard_index: 0.4611
# Epoch 10/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.4846 - accuracy: 0.7799 - jaccard_index: 0.5385 - val_loss: 0.5401 - val_accuracy: 0.7651 - val_jaccard_index: 0.4834
# Epoch 11/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.4711 - accuracy: 0.7885 - jaccard_index: 0.5489 - val_loss: 0.5296 - val_accuracy: 0.7648 - val_jaccard_index: 0.4978
# Epoch 12/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.4519 - accuracy: 0.8003 - jaccard_index: 0.5664 - val_loss: 0.5977 - val_accuracy: 0.7624 - val_jaccard_index: 0.5185
# Epoch 13/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.4393 - accuracy: 0.8071 - jaccard_index: 0.5770 - val_loss: 0.4877 - val_accuracy: 0.7847 - val_jaccard_index: 0.5522
# Epoch 14/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.4434 - accuracy: 0.8082 - jaccard_index: 0.5746 - val_loss: 0.4931 - val_accuracy: 0.7878 - val_jaccard_index: 0.5243
# Epoch 15/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.4276 - accuracy: 0.8140 - jaccard_index: 0.5891 - val_loss: 0.4239 - val_accuracy: 0.8178 - val_jaccard_index: 0.5702
# Epoch 16/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.3983 - accuracy: 0.8307 - jaccard_index: 0.6127 - val_loss: 0.4574 - val_accuracy: 0.8085 - val_jaccard_index: 0.6001
# Epoch 17/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.3833 - accuracy: 0.8390 - jaccard_index: 0.6267 - val_loss: 0.4168 - val_accuracy: 0.8283 - val_jaccard_index: 0.6137
# Epoch 18/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.3790 - accuracy: 0.8405 - jaccard_index: 0.6305 - val_loss: 0.3898 - val_accuracy: 0.8350 - val_jaccard_index: 0.6183
# Epoch 19/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.3759 - accuracy: 0.8426 - jaccard_index: 0.6340 - val_loss: 0.3828 - val_accuracy: 0.8383 - val_jaccard_index: 0.6084
# Epoch 20/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.3661 - accuracy: 0.8473 - jaccard_index: 0.6428 - val_loss: 0.3795 - val_accuracy: 0.8437 - val_jaccard_index: 0.6479
# Epoch 21/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.3493 - accuracy: 0.8544 - jaccard_index: 0.6565 - val_loss: 0.3580 - val_accuracy: 0.8468 - val_jaccard_index: 0.6481
# Epoch 22/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.3386 - accuracy: 0.8595 - jaccard_index: 0.6660 - val_loss: 0.3784 - val_accuracy: 0.8491 - val_jaccard_index: 0.6682
# Epoch 23/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.3430 - accuracy: 0.8575 - jaccard_index: 0.6620 - val_loss: 0.3963 - val_accuracy: 0.8401 - val_jaccard_index: 0.6560
# Epoch 24/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.3403 - accuracy: 0.8584 - jaccard_index: 0.6655 - val_loss: 0.3708 - val_accuracy: 0.8446 - val_jaccard_index: 0.6404
# Epoch 25/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.3313 - accuracy: 0.8634 - jaccard_index: 0.6707 - val_loss: 0.3446 - val_accuracy: 0.8569 - val_jaccard_index: 0.6705
# Epoch 26/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.3143 - accuracy: 0.8715 - jaccard_index: 0.6892 - val_loss: 0.3322 - val_accuracy: 0.8606 - val_jaccard_index: 0.6690
# Epoch 27/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.3073 - accuracy: 0.8746 - jaccard_index: 0.6940 - val_loss: 0.3444 - val_accuracy: 0.8569 - val_jaccard_index: 0.6799
# Epoch 28/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.2997 - accuracy: 0.8779 - jaccard_index: 0.7014 - val_loss: 0.3342 - val_accuracy: 0.8606 - val_jaccard_index: 0.6496
# Epoch 29/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.2983 - accuracy: 0.8789 - jaccard_index: 0.7027 - val_loss: 0.3292 - val_accuracy: 0.8615 - val_jaccard_index: 0.6701
# Epoch 30/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.2887 - accuracy: 0.8830 - jaccard_index: 0.7100 - val_loss: 0.3306 - val_accuracy: 0.8629 - val_jaccard_index: 0.6863
# Epoch 31/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.2817 - accuracy: 0.8860 - jaccard_index: 0.7187 - val_loss: 0.3380 - val_accuracy: 0.8594 - val_jaccard_index: 0.6780
# Epoch 32/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.2725 - accuracy: 0.8905 - jaccard_index: 0.7251 - val_loss: 0.3366 - val_accuracy: 0.8618 - val_jaccard_index: 0.6937
# Epoch 33/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.2640 - accuracy: 0.8944 - jaccard_index: 0.7344 - val_loss: 0.3456 - val_accuracy: 0.8601 - val_jaccard_index: 0.6938
# Epoch 34/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.2585 - accuracy: 0.8968 - jaccard_index: 0.7395 - val_loss: 0.3330 - val_accuracy: 0.8567 - val_jaccard_index: 0.6756
# Epoch 35/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.2573 - accuracy: 0.8979 - jaccard_index: 0.7401 - val_loss: 0.3351 - val_accuracy: 0.8567 - val_jaccard_index: 0.6704
# Epoch 36/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.2543 - accuracy: 0.8989 - jaccard_index: 0.7433 - val_loss: 0.3368 - val_accuracy: 0.8643 - val_jaccard_index: 0.7052
# Epoch 37/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.2369 - accuracy: 0.9068 - jaccard_index: 0.7598 - val_loss: 0.3463 - val_accuracy: 0.8552 - val_jaccard_index: 0.6856
# Epoch 38/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.2410 - accuracy: 0.9045 - jaccard_index: 0.7558 - val_loss: 0.3712 - val_accuracy: 0.8598 - val_jaccard_index: 0.7042
# Epoch 39/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.2364 - accuracy: 0.9069 - jaccard_index: 0.7610 - val_loss: 0.3432 - val_accuracy: 0.8604 - val_jaccard_index: 0.6857
# Epoch 40/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.2256 - accuracy: 0.9116 - jaccard_index: 0.7703 - val_loss: 0.3487 - val_accuracy: 0.8627 - val_jaccard_index: 0.7064
# Epoch 41/200
# 50/50 [==============================] - 2s 44ms/step - loss: 0.2188 - accuracy: 0.9146 - jaccard_index: 0.7771 - val_loss: 0.3423 - val_accuracy: 0.8647 - val_jaccard_index: 0.7073
# Epoch 42/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.2204 - accuracy: 0.9138 - jaccard_index: 0.7761 - val_loss: 0.3503 - val_accuracy: 0.8609 - val_jaccard_index: 0.7028
# Epoch 43/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.2103 - accuracy: 0.9181 - jaccard_index: 0.7849 - val_loss: 0.3518 - val_accuracy: 0.8657 - val_jaccard_index: 0.7177
# Epoch 44/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.2059 - accuracy: 0.9200 - jaccard_index: 0.7904 - val_loss: 0.3533 - val_accuracy: 0.8640 - val_jaccard_index: 0.7107
# Epoch 45/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.2020 - accuracy: 0.9215 - jaccard_index: 0.7930 - val_loss: 0.3757 - val_accuracy: 0.8596 - val_jaccard_index: 0.7133
# Epoch 46/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1975 - accuracy: 0.9232 - jaccard_index: 0.7980 - val_loss: 0.3623 - val_accuracy: 0.8633 - val_jaccard_index: 0.7137
# Epoch 47/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1966 - accuracy: 0.9238 - jaccard_index: 0.7986 - val_loss: 0.3636 - val_accuracy: 0.8576 - val_jaccard_index: 0.7002
# Epoch 48/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1947 - accuracy: 0.9244 - jaccard_index: 0.8004 - val_loss: 0.3781 - val_accuracy: 0.8641 - val_jaccard_index: 0.7199
# Epoch 49/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1916 - accuracy: 0.9258 - jaccard_index: 0.8033 - val_loss: 0.3707 - val_accuracy: 0.8622 - val_jaccard_index: 0.7137
# Epoch 50/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1880 - accuracy: 0.9274 - jaccard_index: 0.8068 - val_loss: 0.3730 - val_accuracy: 0.8607 - val_jaccard_index: 0.7151
# Epoch 51/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1832 - accuracy: 0.9291 - jaccard_index: 0.8114 - val_loss: 0.3773 - val_accuracy: 0.8639 - val_jaccard_index: 0.7220
# Epoch 52/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1825 - accuracy: 0.9293 - jaccard_index: 0.8123 - val_loss: 0.3656 - val_accuracy: 0.8622 - val_jaccard_index: 0.7147
# Epoch 53/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1783 - accuracy: 0.9312 - jaccard_index: 0.8165 - val_loss: 0.3686 - val_accuracy: 0.8642 - val_jaccard_index: 0.7188
# Epoch 54/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1757 - accuracy: 0.9321 - jaccard_index: 0.8183 - val_loss: 0.3733 - val_accuracy: 0.8639 - val_jaccard_index: 0.7214
# Epoch 55/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1780 - accuracy: 0.9312 - jaccard_index: 0.8168 - val_loss: 0.3623 - val_accuracy: 0.8636 - val_jaccard_index: 0.7155
# Epoch 56/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1730 - accuracy: 0.9332 - jaccard_index: 0.8212 - val_loss: 0.3855 - val_accuracy: 0.8596 - val_jaccard_index: 0.7148
# Epoch 57/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1724 - accuracy: 0.9335 - jaccard_index: 0.8220 - val_loss: 0.3672 - val_accuracy: 0.8659 - val_jaccard_index: 0.7218
# Epoch 58/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1708 - accuracy: 0.9340 - jaccard_index: 0.8232 - val_loss: 0.3736 - val_accuracy: 0.8620 - val_jaccard_index: 0.7170
# Epoch 59/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1672 - accuracy: 0.9354 - jaccard_index: 0.8269 - val_loss: 0.3645 - val_accuracy: 0.8662 - val_jaccard_index: 0.7209
# Epoch 60/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1659 - accuracy: 0.9360 - jaccard_index: 0.8281 - val_loss: 0.3657 - val_accuracy: 0.8666 - val_jaccard_index: 0.7237
# Epoch 61/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1670 - accuracy: 0.9355 - jaccard_index: 0.8268 - val_loss: 0.3947 - val_accuracy: 0.8559 - val_jaccard_index: 0.7104
# Epoch 62/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1642 - accuracy: 0.9365 - jaccard_index: 0.8297 - val_loss: 0.3855 - val_accuracy: 0.8669 - val_jaccard_index: 0.7283
# Epoch 63/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1626 - accuracy: 0.9372 - jaccard_index: 0.8311 - val_loss: 0.3845 - val_accuracy: 0.8643 - val_jaccard_index: 0.7233
# Epoch 64/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1603 - accuracy: 0.9380 - jaccard_index: 0.8333 - val_loss: 0.3855 - val_accuracy: 0.8644 - val_jaccard_index: 0.7243
# Epoch 65/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1581 - accuracy: 0.9389 - jaccard_index: 0.8356 - val_loss: 0.4023 - val_accuracy: 0.8654 - val_jaccard_index: 0.7279
# Epoch 66/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1585 - accuracy: 0.9387 - jaccard_index: 0.8346 - val_loss: 0.3988 - val_accuracy: 0.8660 - val_jaccard_index: 0.7295
# Epoch 67/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1570 - accuracy: 0.9393 - jaccard_index: 0.8368 - val_loss: 0.3886 - val_accuracy: 0.8646 - val_jaccard_index: 0.7247
# Epoch 68/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1563 - accuracy: 0.9396 - jaccard_index: 0.8374 - val_loss: 0.3828 - val_accuracy: 0.8656 - val_jaccard_index: 0.7244
# Epoch 69/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1540 - accuracy: 0.9405 - jaccard_index: 0.8392 - val_loss: 0.4013 - val_accuracy: 0.8656 - val_jaccard_index: 0.7289
# Epoch 70/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1525 - accuracy: 0.9410 - jaccard_index: 0.8407 - val_loss: 0.3849 - val_accuracy: 0.8637 - val_jaccard_index: 0.7223
# Epoch 71/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1507 - accuracy: 0.9419 - jaccard_index: 0.8427 - val_loss: 0.3956 - val_accuracy: 0.8667 - val_jaccard_index: 0.7311
# Epoch 72/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1534 - accuracy: 0.9408 - jaccard_index: 0.8402 - val_loss: 0.4021 - val_accuracy: 0.8642 - val_jaccard_index: 0.7275
# Epoch 73/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1513 - accuracy: 0.9413 - jaccard_index: 0.8419 - val_loss: 0.3994 - val_accuracy: 0.8652 - val_jaccard_index: 0.7286
# Epoch 74/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1491 - accuracy: 0.9424 - jaccard_index: 0.8443 - val_loss: 0.3905 - val_accuracy: 0.8662 - val_jaccard_index: 0.7270
# Epoch 75/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1467 - accuracy: 0.9432 - jaccard_index: 0.8463 - val_loss: 0.4114 - val_accuracy: 0.8655 - val_jaccard_index: 0.7311
# Epoch 76/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1476 - accuracy: 0.9429 - jaccard_index: 0.8453 - val_loss: 0.4049 - val_accuracy: 0.8648 - val_jaccard_index: 0.7297
# Epoch 77/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1472 - accuracy: 0.9431 - jaccard_index: 0.8458 - val_loss: 0.4056 - val_accuracy: 0.8658 - val_jaccard_index: 0.7297
# Epoch 78/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1488 - accuracy: 0.9424 - jaccard_index: 0.8445 - val_loss: 0.3875 - val_accuracy: 0.8657 - val_jaccard_index: 0.7275
# Epoch 79/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1460 - accuracy: 0.9436 - jaccard_index: 0.8470 - val_loss: 0.3937 - val_accuracy: 0.8634 - val_jaccard_index: 0.7238
# Epoch 80/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1461 - accuracy: 0.9434 - jaccard_index: 0.8466 - val_loss: 0.4040 - val_accuracy: 0.8678 - val_jaccard_index: 0.7346
# Epoch 81/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1492 - accuracy: 0.9426 - jaccard_index: 0.8448 - val_loss: 0.4027 - val_accuracy: 0.8675 - val_jaccard_index: 0.7346
# Epoch 82/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1439 - accuracy: 0.9444 - jaccard_index: 0.8489 - val_loss: 0.3895 - val_accuracy: 0.8649 - val_jaccard_index: 0.7272
# Epoch 83/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1429 - accuracy: 0.9448 - jaccard_index: 0.8499 - val_loss: 0.4010 - val_accuracy: 0.8680 - val_jaccard_index: 0.7350
# Epoch 84/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1412 - accuracy: 0.9453 - jaccard_index: 0.8519 - val_loss: 0.4075 - val_accuracy: 0.8655 - val_jaccard_index: 0.7303
# Epoch 85/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1422 - accuracy: 0.9450 - jaccard_index: 0.8509 - val_loss: 0.4215 - val_accuracy: 0.8665 - val_jaccard_index: 0.7332
# Epoch 86/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1420 - accuracy: 0.9451 - jaccard_index: 0.8509 - val_loss: 0.4065 - val_accuracy: 0.8634 - val_jaccard_index: 0.7271
# Epoch 87/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1420 - accuracy: 0.9451 - jaccard_index: 0.8508 - val_loss: 0.4123 - val_accuracy: 0.8687 - val_jaccard_index: 0.7363
# Epoch 88/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1417 - accuracy: 0.9451 - jaccard_index: 0.8513 - val_loss: 0.4104 - val_accuracy: 0.8678 - val_jaccard_index: 0.7350
# Epoch 89/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1395 - accuracy: 0.9461 - jaccard_index: 0.8532 - val_loss: 0.4149 - val_accuracy: 0.8661 - val_jaccard_index: 0.7343
# Epoch 90/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1392 - accuracy: 0.9463 - jaccard_index: 0.8543 - val_loss: 0.3933 - val_accuracy: 0.8670 - val_jaccard_index: 0.7314
# Epoch 91/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1384 - accuracy: 0.9464 - jaccard_index: 0.8544 - val_loss: 0.4181 - val_accuracy: 0.8637 - val_jaccard_index: 0.7275
# Epoch 92/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1372 - accuracy: 0.9469 - jaccard_index: 0.8553 - val_loss: 0.4212 - val_accuracy: 0.8676 - val_jaccard_index: 0.7354
# Epoch 93/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1376 - accuracy: 0.9467 - jaccard_index: 0.8550 - val_loss: 0.4436 - val_accuracy: 0.8680 - val_jaccard_index: 0.7400
# Epoch 94/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1353 - accuracy: 0.9477 - jaccard_index: 0.8576 - val_loss: 0.4395 - val_accuracy: 0.8681 - val_jaccard_index: 0.7390
# Epoch 95/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1345 - accuracy: 0.9480 - jaccard_index: 0.8583 - val_loss: 0.4313 - val_accuracy: 0.8673 - val_jaccard_index: 0.7372
# Epoch 96/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1333 - accuracy: 0.9484 - jaccard_index: 0.8597 - val_loss: 0.4109 - val_accuracy: 0.8675 - val_jaccard_index: 0.7340
# Epoch 97/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1335 - accuracy: 0.9484 - jaccard_index: 0.8591 - val_loss: 0.4262 - val_accuracy: 0.8666 - val_jaccard_index: 0.7331
# Epoch 98/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1319 - accuracy: 0.9490 - jaccard_index: 0.8607 - val_loss: 0.4336 - val_accuracy: 0.8678 - val_jaccard_index: 0.7380
# Epoch 99/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1317 - accuracy: 0.9490 - jaccard_index: 0.8607 - val_loss: 0.4390 - val_accuracy: 0.8677 - val_jaccard_index: 0.7397
# Epoch 100/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1320 - accuracy: 0.9489 - jaccard_index: 0.8607 - val_loss: 0.4163 - val_accuracy: 0.8682 - val_jaccard_index: 0.7366
# Epoch 101/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1324 - accuracy: 0.9487 - jaccard_index: 0.8603 - val_loss: 0.4124 - val_accuracy: 0.8676 - val_jaccard_index: 0.7370
# Epoch 102/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1290 - accuracy: 0.9500 - jaccard_index: 0.8634 - val_loss: 0.4413 - val_accuracy: 0.8674 - val_jaccard_index: 0.7378
# Epoch 103/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1304 - accuracy: 0.9495 - jaccard_index: 0.8623 - val_loss: 0.4290 - val_accuracy: 0.8691 - val_jaccard_index: 0.7398
# Epoch 104/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1302 - accuracy: 0.9496 - jaccard_index: 0.8622 - val_loss: 0.4246 - val_accuracy: 0.8682 - val_jaccard_index: 0.7368
# Epoch 105/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1285 - accuracy: 0.9502 - jaccard_index: 0.8640 - val_loss: 0.4543 - val_accuracy: 0.8669 - val_jaccard_index: 0.7396
# Epoch 106/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1291 - accuracy: 0.9499 - jaccard_index: 0.8631 - val_loss: 0.4251 - val_accuracy: 0.8657 - val_jaccard_index: 0.7338
# Epoch 107/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1301 - accuracy: 0.9496 - jaccard_index: 0.8624 - val_loss: 0.4282 - val_accuracy: 0.8671 - val_jaccard_index: 0.7375
# Epoch 108/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1289 - accuracy: 0.9501 - jaccard_index: 0.8637 - val_loss: 0.4146 - val_accuracy: 0.8688 - val_jaccard_index: 0.7375
# Epoch 109/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1278 - accuracy: 0.9505 - jaccard_index: 0.8644 - val_loss: 0.4439 - val_accuracy: 0.8688 - val_jaccard_index: 0.7416
# Epoch 110/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1273 - accuracy: 0.9506 - jaccard_index: 0.8653 - val_loss: 0.4254 - val_accuracy: 0.8664 - val_jaccard_index: 0.7346
# Epoch 111/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1270 - accuracy: 0.9508 - jaccard_index: 0.8654 - val_loss: 0.4336 - val_accuracy: 0.8671 - val_jaccard_index: 0.7372
# Epoch 112/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1256 - accuracy: 0.9512 - jaccard_index: 0.8664 - val_loss: 0.4704 - val_accuracy: 0.8681 - val_jaccard_index: 0.7426
# Epoch 113/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1270 - accuracy: 0.9508 - jaccard_index: 0.8656 - val_loss: 0.4499 - val_accuracy: 0.8650 - val_jaccard_index: 0.7345
# Epoch 114/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1262 - accuracy: 0.9511 - jaccard_index: 0.8661 - val_loss: 0.4330 - val_accuracy: 0.8663 - val_jaccard_index: 0.7356
# Epoch 115/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1715 - accuracy: 0.9345 - jaccard_index: 0.8257 - val_loss: 0.4361 - val_accuracy: 0.8475 - val_jaccard_index: 0.6990
# Epoch 116/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1555 - accuracy: 0.9403 - jaccard_index: 0.8382 - val_loss: 0.4227 - val_accuracy: 0.8627 - val_jaccard_index: 0.7285
# Epoch 117/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1363 - accuracy: 0.9472 - jaccard_index: 0.8563 - val_loss: 0.4185 - val_accuracy: 0.8654 - val_jaccard_index: 0.7318
# Epoch 118/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1336 - accuracy: 0.9484 - jaccard_index: 0.8591 - val_loss: 0.4288 - val_accuracy: 0.8690 - val_jaccard_index: 0.7417
# Epoch 119/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1290 - accuracy: 0.9501 - jaccard_index: 0.8638 - val_loss: 0.4207 - val_accuracy: 0.8687 - val_jaccard_index: 0.7396
# Epoch 120/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1259 - accuracy: 0.9513 - jaccard_index: 0.8665 - val_loss: 0.4409 - val_accuracy: 0.8688 - val_jaccard_index: 0.7429
# Epoch 121/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1234 - accuracy: 0.9521 - jaccard_index: 0.8687 - val_loss: 0.4488 - val_accuracy: 0.8690 - val_jaccard_index: 0.7422
# Epoch 122/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1227 - accuracy: 0.9524 - jaccard_index: 0.8696 - val_loss: 0.4527 - val_accuracy: 0.8694 - val_jaccard_index: 0.7444
# Epoch 123/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1221 - accuracy: 0.9525 - jaccard_index: 0.8701 - val_loss: 0.4553 - val_accuracy: 0.8695 - val_jaccard_index: 0.7438
# Epoch 124/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1214 - accuracy: 0.9528 - jaccard_index: 0.8707 - val_loss: 0.4362 - val_accuracy: 0.8685 - val_jaccard_index: 0.7409
# Epoch 125/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1220 - accuracy: 0.9526 - jaccard_index: 0.8704 - val_loss: 0.4342 - val_accuracy: 0.8682 - val_jaccard_index: 0.7389
# Epoch 126/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1220 - accuracy: 0.9527 - jaccard_index: 0.8705 - val_loss: 0.4260 - val_accuracy: 0.8692 - val_jaccard_index: 0.7394
# Epoch 127/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1221 - accuracy: 0.9525 - jaccard_index: 0.8698 - val_loss: 0.4425 - val_accuracy: 0.8700 - val_jaccard_index: 0.7418
# Epoch 128/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1205 - accuracy: 0.9532 - jaccard_index: 0.8716 - val_loss: 0.4458 - val_accuracy: 0.8700 - val_jaccard_index: 0.7437
# Epoch 129/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1203 - accuracy: 0.9532 - jaccard_index: 0.8717 - val_loss: 0.4528 - val_accuracy: 0.8694 - val_jaccard_index: 0.7431
# Epoch 130/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1196 - accuracy: 0.9535 - jaccard_index: 0.8724 - val_loss: 0.4576 - val_accuracy: 0.8703 - val_jaccard_index: 0.7461
# Epoch 131/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1200 - accuracy: 0.9534 - jaccard_index: 0.8722 - val_loss: 0.4379 - val_accuracy: 0.8685 - val_jaccard_index: 0.7396
# Epoch 132/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1203 - accuracy: 0.9533 - jaccard_index: 0.8719 - val_loss: 0.4516 - val_accuracy: 0.8709 - val_jaccard_index: 0.7463
# Epoch 133/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1197 - accuracy: 0.9534 - jaccard_index: 0.8723 - val_loss: 0.4249 - val_accuracy: 0.8685 - val_jaccard_index: 0.7404
# Epoch 134/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1192 - accuracy: 0.9537 - jaccard_index: 0.8731 - val_loss: 0.4453 - val_accuracy: 0.8680 - val_jaccard_index: 0.7400
# Epoch 135/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1190 - accuracy: 0.9538 - jaccard_index: 0.8731 - val_loss: 0.4282 - val_accuracy: 0.8698 - val_jaccard_index: 0.7419
# Epoch 136/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1184 - accuracy: 0.9539 - jaccard_index: 0.8734 - val_loss: 0.4633 - val_accuracy: 0.8691 - val_jaccard_index: 0.7443
# Epoch 137/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1188 - accuracy: 0.9537 - jaccard_index: 0.8733 - val_loss: 0.4496 - val_accuracy: 0.8708 - val_jaccard_index: 0.7451
# Epoch 138/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1181 - accuracy: 0.9539 - jaccard_index: 0.8738 - val_loss: 0.4427 - val_accuracy: 0.8680 - val_jaccard_index: 0.7391
# Epoch 139/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1188 - accuracy: 0.9538 - jaccard_index: 0.8731 - val_loss: 0.4571 - val_accuracy: 0.8711 - val_jaccard_index: 0.7480
# Epoch 140/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1177 - accuracy: 0.9542 - jaccard_index: 0.8742 - val_loss: 0.4771 - val_accuracy: 0.8687 - val_jaccard_index: 0.7439
# Epoch 141/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1179 - accuracy: 0.9541 - jaccard_index: 0.8741 - val_loss: 0.4343 - val_accuracy: 0.8677 - val_jaccard_index: 0.7375
# Epoch 142/200
# 50/50 [==============================] - 2s 43ms/step - loss: 0.1166 - accuracy: 0.9546 - jaccard_index: 0.8754 - val_loss: 0.4749 - val_accuracy: 0.8698 - val_jaccard_index: 0.7455
# Epoch 143/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1177 - accuracy: 0.9542 - jaccard_index: 0.8742 - val_loss: 0.4588 - val_accuracy: 0.8711 - val_jaccard_index: 0.7461
# Epoch 144/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1163 - accuracy: 0.9547 - jaccard_index: 0.8755 - val_loss: 0.4639 - val_accuracy: 0.8708 - val_jaccard_index: 0.7479
# Epoch 145/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1166 - accuracy: 0.9546 - jaccard_index: 0.8752 - val_loss: 0.4626 - val_accuracy: 0.8697 - val_jaccard_index: 0.7442
# Epoch 146/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1167 - accuracy: 0.9546 - jaccard_index: 0.8754 - val_loss: 0.4388 - val_accuracy: 0.8688 - val_jaccard_index: 0.7396
# Epoch 147/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1172 - accuracy: 0.9544 - jaccard_index: 0.8748 - val_loss: 0.4406 - val_accuracy: 0.8692 - val_jaccard_index: 0.7402
# Epoch 148/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1175 - accuracy: 0.9543 - jaccard_index: 0.8745 - val_loss: 0.4533 - val_accuracy: 0.8691 - val_jaccard_index: 0.7426
# Epoch 149/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1172 - accuracy: 0.9542 - jaccard_index: 0.8746 - val_loss: 0.4666 - val_accuracy: 0.8698 - val_jaccard_index: 0.7451
# Epoch 150/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1172 - accuracy: 0.9543 - jaccard_index: 0.8746 - val_loss: 0.4515 - val_accuracy: 0.8700 - val_jaccard_index: 0.7443
# Epoch 151/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1161 - accuracy: 0.9547 - jaccard_index: 0.8756 - val_loss: 0.4688 - val_accuracy: 0.8698 - val_jaccard_index: 0.7458
# Epoch 152/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1168 - accuracy: 0.9545 - jaccard_index: 0.8749 - val_loss: 0.4963 - val_accuracy: 0.8710 - val_jaccard_index: 0.7495
# Epoch 153/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1226 - accuracy: 0.9524 - jaccard_index: 0.8697 - val_loss: 0.4745 - val_accuracy: 0.8655 - val_jaccard_index: 0.7369
# Epoch 154/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1228 - accuracy: 0.9524 - jaccard_index: 0.8696 - val_loss: 0.4621 - val_accuracy: 0.8656 - val_jaccard_index: 0.7385
# Epoch 155/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1181 - accuracy: 0.9541 - jaccard_index: 0.8739 - val_loss: 0.4680 - val_accuracy: 0.8692 - val_jaccard_index: 0.7435
# Epoch 156/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1151 - accuracy: 0.9551 - jaccard_index: 0.8770 - val_loss: 0.4436 - val_accuracy: 0.8714 - val_jaccard_index: 0.7465
# Epoch 157/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1149 - accuracy: 0.9552 - jaccard_index: 0.8766 - val_loss: 0.4560 - val_accuracy: 0.8690 - val_jaccard_index: 0.7434
# Epoch 158/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1139 - accuracy: 0.9556 - jaccard_index: 0.8780 - val_loss: 0.4505 - val_accuracy: 0.8705 - val_jaccard_index: 0.7441
# Epoch 159/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1133 - accuracy: 0.9557 - jaccard_index: 0.8787 - val_loss: 0.4520 - val_accuracy: 0.8708 - val_jaccard_index: 0.7452
# Epoch 160/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1133 - accuracy: 0.9558 - jaccard_index: 0.8783 - val_loss: 0.4665 - val_accuracy: 0.8692 - val_jaccard_index: 0.7433
# Epoch 161/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1127 - accuracy: 0.9561 - jaccard_index: 0.8793 - val_loss: 0.4451 - val_accuracy: 0.8686 - val_jaccard_index: 0.7418
# Epoch 162/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1144 - accuracy: 0.9555 - jaccard_index: 0.8775 - val_loss: 0.4351 - val_accuracy: 0.8693 - val_jaccard_index: 0.7405
# Epoch 163/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1158 - accuracy: 0.9549 - jaccard_index: 0.8760 - val_loss: 0.4667 - val_accuracy: 0.8694 - val_jaccard_index: 0.7461
# Epoch 164/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1142 - accuracy: 0.9553 - jaccard_index: 0.8776 - val_loss: 0.4445 - val_accuracy: 0.8675 - val_jaccard_index: 0.7366
# Epoch 165/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1160 - accuracy: 0.9549 - jaccard_index: 0.8760 - val_loss: 0.4543 - val_accuracy: 0.8703 - val_jaccard_index: 0.7451
# Epoch 166/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1152 - accuracy: 0.9550 - jaccard_index: 0.8765 - val_loss: 0.4508 - val_accuracy: 0.8704 - val_jaccard_index: 0.7439
# Epoch 167/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1144 - accuracy: 0.9553 - jaccard_index: 0.8772 - val_loss: 0.4705 - val_accuracy: 0.8714 - val_jaccard_index: 0.7491
# Epoch 168/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1131 - accuracy: 0.9558 - jaccard_index: 0.8784 - val_loss: 0.4450 - val_accuracy: 0.8692 - val_jaccard_index: 0.7410
# Epoch 169/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1129 - accuracy: 0.9559 - jaccard_index: 0.8789 - val_loss: 0.4484 - val_accuracy: 0.8713 - val_jaccard_index: 0.7453
# Epoch 170/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1119 - accuracy: 0.9563 - jaccard_index: 0.8800 - val_loss: 0.4617 - val_accuracy: 0.8690 - val_jaccard_index: 0.7435
# Epoch 171/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1121 - accuracy: 0.9562 - jaccard_index: 0.8795 - val_loss: 0.4402 - val_accuracy: 0.8704 - val_jaccard_index: 0.7431
# Epoch 172/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1107 - accuracy: 0.9566 - jaccard_index: 0.8807 - val_loss: 0.4816 - val_accuracy: 0.8712 - val_jaccard_index: 0.7489
# Epoch 173/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1107 - accuracy: 0.9567 - jaccard_index: 0.8809 - val_loss: 0.4733 - val_accuracy: 0.8706 - val_jaccard_index: 0.7473
# Epoch 174/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1112 - accuracy: 0.9564 - jaccard_index: 0.8804 - val_loss: 0.4886 - val_accuracy: 0.8714 - val_jaccard_index: 0.7497
# Epoch 175/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1101 - accuracy: 0.9569 - jaccard_index: 0.8814 - val_loss: 0.4559 - val_accuracy: 0.8712 - val_jaccard_index: 0.7480
# Epoch 176/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1108 - accuracy: 0.9567 - jaccard_index: 0.8809 - val_loss: 0.4651 - val_accuracy: 0.8700 - val_jaccard_index: 0.7453
# Epoch 177/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1120 - accuracy: 0.9562 - jaccard_index: 0.8796 - val_loss: 0.4593 - val_accuracy: 0.8702 - val_jaccard_index: 0.7453
# Epoch 178/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1129 - accuracy: 0.9558 - jaccard_index: 0.8782 - val_loss: 0.5150 - val_accuracy: 0.8702 - val_jaccard_index: 0.7508
# Epoch 179/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1163 - accuracy: 0.9546 - jaccard_index: 0.8757 - val_loss: 0.4731 - val_accuracy: 0.8720 - val_jaccard_index: 0.7499
# Epoch 180/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1158 - accuracy: 0.9549 - jaccard_index: 0.8759 - val_loss: 0.4423 - val_accuracy: 0.8679 - val_jaccard_index: 0.7403
# Epoch 181/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1151 - accuracy: 0.9550 - jaccard_index: 0.8766 - val_loss: 0.4762 - val_accuracy: 0.8705 - val_jaccard_index: 0.7457
# Epoch 182/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1123 - accuracy: 0.9560 - jaccard_index: 0.8790 - val_loss: 0.4725 - val_accuracy: 0.8711 - val_jaccard_index: 0.7501
# Epoch 183/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1113 - accuracy: 0.9565 - jaccard_index: 0.8805 - val_loss: 0.4545 - val_accuracy: 0.8699 - val_jaccard_index: 0.7434
# Epoch 184/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1101 - accuracy: 0.9569 - jaccard_index: 0.8816 - val_loss: 0.4422 - val_accuracy: 0.8706 - val_jaccard_index: 0.7429
# Epoch 185/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1102 - accuracy: 0.9569 - jaccard_index: 0.8814 - val_loss: 0.4709 - val_accuracy: 0.8709 - val_jaccard_index: 0.7470
# Epoch 186/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1095 - accuracy: 0.9571 - jaccard_index: 0.8819 - val_loss: 0.4754 - val_accuracy: 0.8733 - val_jaccard_index: 0.7528
# Epoch 187/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1092 - accuracy: 0.9571 - jaccard_index: 0.8822 - val_loss: 0.4753 - val_accuracy: 0.8719 - val_jaccard_index: 0.7496
# Epoch 188/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1090 - accuracy: 0.9574 - jaccard_index: 0.8826 - val_loss: 0.4510 - val_accuracy: 0.8706 - val_jaccard_index: 0.7441
# Epoch 189/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1121 - accuracy: 0.9561 - jaccard_index: 0.8791 - val_loss: 0.5105 - val_accuracy: 0.8658 - val_jaccard_index: 0.7426
# Epoch 190/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1166 - accuracy: 0.9546 - jaccard_index: 0.8755 - val_loss: 0.4675 - val_accuracy: 0.8713 - val_jaccard_index: 0.7487
# Epoch 191/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1109 - accuracy: 0.9566 - jaccard_index: 0.8805 - val_loss: 0.4910 - val_accuracy: 0.8715 - val_jaccard_index: 0.7497
# Epoch 192/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1113 - accuracy: 0.9565 - jaccard_index: 0.8803 - val_loss: 0.4418 - val_accuracy: 0.8657 - val_jaccard_index: 0.7339
# Epoch 193/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1558 - accuracy: 0.9410 - jaccard_index: 0.8396 - val_loss: 0.4052 - val_accuracy: 0.8568 - val_jaccard_index: 0.7113
# Epoch 194/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1424 - accuracy: 0.9450 - jaccard_index: 0.8505 - val_loss: 0.4645 - val_accuracy: 0.8634 - val_jaccard_index: 0.7346
# Epoch 195/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1208 - accuracy: 0.9528 - jaccard_index: 0.8709 - val_loss: 0.4294 - val_accuracy: 0.8709 - val_jaccard_index: 0.7445
# Epoch 196/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1142 - accuracy: 0.9554 - jaccard_index: 0.8774 - val_loss: 0.4569 - val_accuracy: 0.8704 - val_jaccard_index: 0.7454
# Epoch 197/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1133 - accuracy: 0.9557 - jaccard_index: 0.8784 - val_loss: 0.4778 - val_accuracy: 0.8692 - val_jaccard_index: 0.7462
# Epoch 198/200
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1093 - accuracy: 0.9572 - jaccard_index: 0.8822 - val_loss: 0.4528 - val_accuracy: 0.8723 - val_jaccard_index: 0.7487
# Epoch 199/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1081 - accuracy: 0.9575 - jaccard_index: 0.8832 - val_loss: 0.4634 - val_accuracy: 0.8713 - val_jaccard_index: 0.7477
# Epoch 200/200
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1078 - accuracy: 0.9578 - jaccard_index: 0.8836 - val_loss: 0.4650 - val_accuracy: 0.8720 - val_jaccard_index: 0.7499

# %%
model_json = model_U.to_json()
with open("model_U.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
# model_U.save_weights("model_Unburn_V01.h5")
model_U.save("model_Unburn_test.h5")

# %%
fig , ax = plt.subplots(1,2)
fig.set_size_inches(25,8)

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

epochs = range(1, len(train_acc) + 1)

ax[0].plot(epochs , train_acc , 'g-o' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'y-o' , label = 'Validation Accuracy')
ax[0].set_title('Model Training & Validation Accuracy')
ax[0].legend(loc = 'lower right')
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'y-o' , label = 'Validation Loss')
ax[1].set_title('Model Training & Validation & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")

plt.show()

# %%
#Predict
def rgb_encode_mask(mask):
    # initialize rgb image with equal spatial resolution
    rgb_encode_image = np.zeros((mask.shape[0], mask.shape[1], 3))

    # iterate over MaskColorMap
    for j, cls in enumerate(MaskColorMap):
        # convert single integer channel to RGB channels
        rgb_encode_image[(mask == j)] = np.array(cls.value) / 255.
    return rgb_encode_image

# %%
for _ in range(3):
#     Y_testimg
    print(f'Total test image: {len(X_testimg)}')
    # choose random number from 0 to test set size
    test_img_number = np.random.randint(0, len(X_testimg))
    print(f'Number of test image: {test_img_number}')
    
    # extract test input image
    test_img = X_testimg[test_img_number]
    # print(test_img)
    
    # ground truth test label converted from one-hot to integer encoding
    ground_truth = np.argmax(Y_unet_test[test_img_number], axis=-1)

    # expand first dimension as U-Net requires (m, h, w, nc) input shape
    test_img_input = np.expand_dims(test_img, 0)

    # make prediction with model and remove extra dimension
    prediction = np.squeeze(model_U.predict(test_img_input))

    # convert softmax probabilities to integer values
    predicted_img = np.argmax(prediction, axis=-1)

    # convert integer encoding to rgb values
    rgb_image = rgb_encode_mask(predicted_img)
    rgb_ground_truth = rgb_encode_mask(ground_truth)

    # visualize model predictions
    display_images(
        [test_img, ground_truth, rgb_image],
        rows=1, titles=['Original', 'Ground Truth', 'Prediction']
    )
    display_images(
        [test_img, rgb_ground_truth, rgb_image],
        rows=1, titles=['Original', 'Ground Truth', 'Prediction']
    )
# Out:
# Total test image: 10
# Number of test image: 4
# Total test image: 10
# Number of test image: 5
# Total test image: 10
# Number of test image: 9
